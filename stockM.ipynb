# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejajulakanti/Stock-Market/blob/main/stockM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
import io
import os

training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#      <input type="file" id="files-27e75bee-fff6-4dde-8175-116880190ade" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27e75bee-fff6-4dde-8175-116880190ade">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train.csv
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 2ms/step - loss: 0.8240
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6733
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5520
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4544
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3761
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3126
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2618
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2207
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1878
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1614
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1406
# Epoch 12/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1241
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1113
# Epoch 14/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1014
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0938
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0881
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0806
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0783
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0766
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0754
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0744
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0736
# Epoch 24/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0730
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0724
# Epoch 26/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0718
# Epoch 27/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0713
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0702
# Epoch 30/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0696
# Epoch 31/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0691
# Epoch 32/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0685
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0679
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0673
# Epoch 35/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0666
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0652
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0645
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0637
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0630
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0621
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0613
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0604
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0554
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0543
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0532
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0520
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0509
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0496
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0483
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0470
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0456
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0428
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0413
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0398
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 63/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0352
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0320
# Epoch 66/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0304
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0288
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0272
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 71/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0210
# Epoch 73/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 74/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 75/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 76/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 77/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 78/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 79/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 80/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 81/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 82/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 83/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 84/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 85/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 86/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 87/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 88/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 89/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 90/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 91/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 92/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 93/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 94/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 95/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 96/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 97/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 98/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 99/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 100/200
# 40/40 [==============================] - 0s 2ms/step - loss: 9.4875e-04
# Epoch 101/200
# 40/40 [==============================] - 0s 2ms/step - loss: 8.7086e-04
# Epoch 102/200
# 40/40 [==============================] - 0s 2ms/step - loss: 8.0973e-04
# Epoch 103/200
# 40/40 [==============================] - 0s 2ms/step - loss: 7.5788e-04
# Epoch 104/200
# 40/40 [==============================] - 0s 2ms/step - loss: 7.1434e-04
# Epoch 105/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.7961e-04
# Epoch 106/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.4978e-04
# Epoch 107/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.2639e-04
# Epoch 108/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.0623e-04
# Epoch 109/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.8971e-04
# Epoch 110/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.7400e-04
# Epoch 111/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.6066e-04
# Epoch 112/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.5072e-04
# Epoch 113/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.3982e-04
# Epoch 114/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.3108e-04
# Epoch 115/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.2274e-04
# Epoch 116/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.1369e-04
# Epoch 117/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5.0482e-04
# Epoch 118/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.9766e-04
# Epoch 119/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.9007e-04
# Epoch 120/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.8417e-04
# Epoch 121/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.7736e-04
# Epoch 122/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.7133e-04
# Epoch 123/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.6429e-04
# Epoch 124/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.5854e-04
# Epoch 125/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.5175e-04
# Epoch 126/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.4679e-04
# Epoch 127/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.4009e-04
# Epoch 128/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.3425e-04
# Epoch 129/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.2863e-04
# Epoch 130/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.2322e-04
# Epoch 131/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.1802e-04
# Epoch 132/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.1272e-04
# Epoch 133/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0795e-04
# Epoch 134/200
# 40/40 [==============================] - 0s 2ms/step - loss: 4.0235e-04
# Epoch 135/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.9789e-04
# Epoch 136/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.9301e-04
# Epoch 137/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8929e-04
# Epoch 138/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8363e-04
# Epoch 139/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.8008e-04
# Epoch 140/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7552e-04
# Epoch 141/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.7154e-04
# Epoch 142/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6860e-04
# Epoch 143/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6443e-04
# Epoch 144/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.6009e-04
# Epoch 145/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5656e-04
# Epoch 146/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5283e-04
# Epoch 147/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4945e-04
# Epoch 148/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4619e-04
# Epoch 149/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4263e-04
# Epoch 150/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3982e-04
# Epoch 151/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3664e-04
# Epoch 152/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3510e-04
# Epoch 153/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.3178e-04
# Epoch 154/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2852e-04
# Epoch 155/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2608e-04
# Epoch 156/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2354e-04
# Epoch 157/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2153e-04
# Epoch 158/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1858e-04
# Epoch 159/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1684e-04
# Epoch 160/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1583e-04
# Epoch 161/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1295e-04
# Epoch 162/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1033e-04
# Epoch 163/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0868e-04
# Epoch 164/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0723e-04
# Epoch 165/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0468e-04
# Epoch 166/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0371e-04
# Epoch 167/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0254e-04
# Epoch 168/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.0012e-04
# Epoch 169/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9931e-04
# Epoch 170/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9667e-04
# Epoch 171/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9698e-04
# Epoch 172/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9415e-04
# Epoch 173/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9345e-04
# Epoch 174/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9271e-04
# Epoch 175/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.9151e-04
# Epoch 176/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8959e-04
# Epoch 177/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8995e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8815e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8753e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8632e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8517e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8424e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8343e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8355e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8194e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8076e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7938e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8000e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7974e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7986e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8037e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7728e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7774e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7666e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7728e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7713e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7481e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7465e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7470e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7399e-04

# %%
# getting the real stock of 2017 i.e., importing the test dataset
uploaded = files.upload()
test_data = pd.read_csv('/content/Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      <input type="file" id="files-251d7d4d-ee11-4c99-9eec-51289fe1179c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-251d7d4d-ee11-4c99-9eec-51289fe1179c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test.csv
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[772.08954],
#        [779.70386],
#        [777.90106],
#        [785.1026 ],
#        [793.63513],
#        [794.7365 ],
#        [792.5753 ],
#        [794.1939 ],
#        [794.45026],
#        [794.1486 ],
#        [793.189  ],
#        [792.66626],
#        [794.0203 ],
#        [794.27686],
#        [805.4179 ],
#        [810.6854 ],
#        [816.4614 ],
#        [814.28973],
#        [799.8145 ],
#        [786.3421 ]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('/content/Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
